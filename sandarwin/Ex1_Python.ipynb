# %% [markdown]
# <a href="https://colab.research.google.com/github/swhom/MMDT_T-PY101_Batch03/blob/main/sandarwin/Ex1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
temp_feranhite = input ('Enter temperature in Feranhite: ')
temp_celsius= int(temp_feranhite)*-17.2222
print('{} feranhite is equivalent to {} celsius'.format(temp_feranhite,temp_celsius))
# Out:
# Enter temperature in Feranhite: 1
# 1 feranhite is equivalent to -17.2222 celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple = int (input ('number of apple: '))
apple_price =int( input ('apple price:'))
orange = int (input ('number of orange: '))
orange_price =int(input ('orange price:'))
mango = int(input ('number of mango: '))
mango_price = int(input ('magno price:'))

total_cost =(apple*apple_price)+(orange*orange_price)+(mango*mango_price)
print ("Total cost for all items is {}".format (total_cost))
# Out:
# number of apple: 1
# apple price:100
# number of orange: 2
# orange price:100
# number of mango: 3
# magno price:100
# Total cost for all items is 600

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
name = input('customer name: ')
print ('Hello' , name)
# Out:
# customer name: sandarwin
# Hello sandarwin

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
y = randint(2,5)
print('A random number between 1 and 50: ', x)
print('A random number between 2 and 5: ', y)
print (x*y)
# Out:
# A random number between 1 and 50:  23
# A random number between 2 and 5:  2
# 46

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x = randint(1,10)
print('A random number between 1 and 10: ', x)
print (x* 'Sandar_Win')
# Out:
# A random number between 1 and 10:  8
# Sandar_WinSandar_WinSandar_WinSandar_WinSandar_WinSandar_WinSandar_WinSandar_Win

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = int(input ('please input first number: '))
y =int (input( 'please input second number: '))
print (abs(x-y)/(x+y))
# Out:
# please input first number: 1
# please input second number: 2
# 0.3333333333333333

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
x = int(input ('how many seconds: '))
minutes = x//60
print (minutes)
seconds = x % 60
print (seconds)
print ('{} seconds is {} minutes and {} seconds'.format (x, minutes, seconds))
# Out:
# how many seconds: 62
# 1
# 2
# 62 seconds is 1 minutes and 2 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
num = float(input("Enter a number:"))
sine_value = math.sin(num)
print(sine_value)
cos_value = math.cos(num)
print(cos_value)
tan_value = math.tan(num)
print(tan_value)
# Out:
# Enter a number:1
# 0.8414709848078965
# 0.5403023058681398
# 1.5574077246549023
